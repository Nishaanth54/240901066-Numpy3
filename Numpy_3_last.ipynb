# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishaanth54/240901066-Numpy3/blob/main/Numpy_3_last.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Filter
import numpy as np
arr=np.array([41,42,43,44])
x=[True,False,True,False]
newarr=arr[x]
print("\n Original array:",arr)
print("\n Filter index:",x)
print("\n Filter array:",newarr)
# Out:
#  Original array: [41 42 43 44]
#
#  Filter index: [True, False, True, False]
#
#  Filter array: [41 43]

# %%
import numpy as np
arr=np.array([41,42,43,44])
filter_arr = arr>42
newarr = arr[filter_arr]
print("\n Original array:",arr)
print("\n Filter array:condition->42:",filter_arr)
print("\n New array:",newarr)
# Out:
#  Original array: [41 42 43 44]
#
#  Filter array:condition->42: [False False  True  True]
#
#  New array: [43 44]
